# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
df = pd.read_csv('training_dataset.csv')
num_rows = df.shape[0]
num_rows
# Out:
# 22916

# %%
df
# Out:
#        customer_number  usia               pekerjaan status_perkawinan  \
# 0               531036    63  sosial media specialis           menikah
# 1               999241    43                 teknisi           menikah
# 2               995002    29  sosial media specialis            lajang
# 3               932750    40           pekerja kasar           menikah
# 4               684699    40  sosial media specialis            lajang
# ...                ...   ...                     ...               ...
# 22911           680377    32                 teknisi           menikah
# 22912           505429    30               mahasiswa            lajang
# 22913           308952    29                 manajer            lajang
# 22914           865813    52            entrepreneur           menikah
# 22915           977067    49           pekerja kasar           menikah
#
#               pendidikan gagal_bayar_sebelumnya pinjaman_rumah  \
# 0      Pendidikan Tinggi                     no            yes
# 1      Pendidikan Tinggi                     no            yes
# 2      Pendidikan Tinggi                     no            yes
# 3                    SMA                     no             no
# 4      Pendidikan Tinggi                     no             no
# ...                  ...                    ...            ...
# 22911            Diploma                     no            yes
# 22912            Diploma                     no             no
# 22913                SMA                     no            yes
# 22914     Tidak Tamat SD                unknown            yes
# 22915     Tidak Tamat SD                unknown            yes
#
#       pinjaman_pribadi jenis_kontak bulan_kontak_terakhir  ...  \
# 0                   no     cellular                   jul  ...
# 1                   no     cellular                   nov  ...
# 2                  yes     cellular                   jul  ...
# 3                   no    telephone                   may  ...
# 4                   no     cellular                   aug  ...
# ...                ...          ...                   ...  ...
# 22911               no     cellular                   aug  ...
# 22912               no    telephone                   sep  ...
# 22913               no     cellular                   jul  ...
# 22914               no    telephone                   jun  ...
# 22915               no    telephone                   may  ...
#
#       hari_sejak_kontak_sebelumnya  jumlah_kontak_sebelumnya  \
# 0                              999                         0
# 1                              999                         0
# 2                              999                         0
# 3                              999                         0
# 4                              999                         0
# ...                            ...                       ...
# 22911                          999                         0
# 22912                          999                         0
# 22913                          999                         0
# 22914                          999                         0
# 22915                          999                         0
#
#        hasil_kampanye_sebelumnya  tingkat_variasi_pekerjaan  \
# 0                    nonexistent                       -1.7
# 1                    nonexistent                       -0.1
# 2                    nonexistent                        1.4
# 3                    nonexistent                        1.1
# 4                    nonexistent                        1.4
# ...                          ...                        ...
# 22911                nonexistent                        1.4
# 22912                nonexistent                       -1.1
# 22913                nonexistent                        1.4
# 22914                nonexistent                        1.4
# 22915                nonexistent                        1.1
#
#       indeks_harga_konsumen  indeks_kepercayaan_konsumen  \
# 0                    94.215                        -40.3
# 1                    93.200                        -42.0
# 2                    93.918                        -42.7
# 3                    93.994                        -36.4
# 4                    93.444                        -36.1
# ...                     ...                          ...
# 22911                93.444                        -36.1
# 22912                94.199                        -37.5
# 22913                93.918                        -42.7
# 22914                94.465                        -41.8
# 22915                93.994                        -36.4
#
#        suku_bunga_euribor_3bln  jumlah_pekerja       pulau  \
# 0                        0.885          4991.6       Papua
# 1                        4.021          5195.8    Sulawesi
# 2                        4.958          5228.1       Papua
# 3                        4.859          5191.0    Sumatera
# 4                        4.964          5228.1        Bali
# ...                        ...             ...         ...
# 22911                    4.967          5228.1  Kalimantan
# 22912                    0.880          4963.6        Bali
# 22913                    4.962          5228.1         NTT
# 22914                    4.960          5228.1         NTB
# 22915                    4.855          5191.0       Papua
#
#        berlangganan_deposito
# 0                          1
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 22911                      0
# 22912                      0
# 22913                      0
# 22914                      0
# 22915                      0
#
# [22916 rows x 22 columns]

# %%
df2 = pd.read_csv('validation_set.csv')
num_rows = df2.shape[0]
num_rows
# Out:
# 5729

# %%
df2
# Out:
#       customer_number  usia               pekerjaan status_perkawinan  \
# 0              445420    35           penyedia jasa           menikah
# 1              585604    52                 teknisi            lajang
# 2              888824    37           pekerja kasar           menikah
# 3              816820    51            pengangguran           menikah
# 4              542716    45                 teknisi             cerai
# ...               ...   ...                     ...               ...
# 5724           782072    51           pekerja kasar           menikah
# 5725           116371    30           pekerja kasar           menikah
# 5726           773759    45           pekerja kasar           menikah
# 5727           612330    60                 teknisi           menikah
# 5728           986050    46  sosial media specialis            lajang
#
#           pendidikan gagal_bayar_sebelumnya pinjaman_rumah pinjaman_pribadi  \
# 0                SMA                     no            yes              yes
# 1            Diploma                unknown             no               no
# 2                SMP                unknown            yes               no
# 3            Diploma                     no             no               no
# 4                SMA                     no            yes               no
# ...              ...                    ...            ...              ...
# 5724  Tidak Tamat SD                     no            yes               no
# 5725             SMP                     no            yes              yes
# 5726             SMP                unknown            yes               no
# 5727         Diploma                unknown             no               no
# 5728             SMA                     no             no               no
#
#      jenis_kontak bulan_kontak_terakhir  ... jumlah_kontak_kampanye_ini  \
# 0        cellular                   jul  ...                          1
# 1       telephone                   may  ...                          4
# 2       telephone                   may  ...                          3
# 3       telephone                   may  ...                          3
# 4        cellular                   may  ...                          1
# ...           ...                   ...  ...                        ...
# 5724    telephone                   jun  ...                          1
# 5725    telephone                   may  ...                          1
# 5726    telephone                   may  ...                          1
# 5727    telephone                   jul  ...                         15
# 5728    telephone                   jun  ...                          1
#
#       hari_sejak_kontak_sebelumnya  jumlah_kontak_sebelumnya  \
# 0                              999                         0
# 1                              999                         0
# 2                              999                         0
# 3                              999                         0
# 4                              999                         1
# ...                            ...                       ...
# 5724                           999                         0
# 5725                           999                         0
# 5726                           999                         0
# 5727                           999                         0
# 5728                           999                         0
#
#       hasil_kampanye_sebelumnya tingkat_variasi_pekerjaan  \
# 0                   nonexistent                       1.4
# 1                   nonexistent                       1.1
# 2                   nonexistent                       1.1
# 3                   nonexistent                       1.1
# 4                       failure                      -1.8
# ...                         ...                       ...
# 5724                nonexistent                       1.4
# 5725                nonexistent                       1.1
# 5726                nonexistent                       1.1
# 5727                nonexistent                       1.4
# 5728                nonexistent                       1.4
#
#       indeks_harga_konsumen  indeks_kepercayaan_konsumen  \
# 0                    93.918                        -42.7
# 1                    93.994                        -36.4
# 2                    93.994                        -36.4
# 3                    93.994                        -36.4
# 4                    92.893                        -46.2
# ...                     ...                          ...
# 5724                 94.465                        -41.8
# 5725                 93.994                        -36.4
# 5726                 93.994                        -36.4
# 5727                 93.918                        -42.7
# 5728                 94.465                        -41.8
#
#       suku_bunga_euribor_3bln  jumlah_pekerja       pulau
# 0                       4.960          5228.1        Jawa
# 1                       4.860          5191.0       Papua
# 2                       4.856          5191.0        Bali
# 3                       4.857          5191.0    Sumatera
# 4                       1.327          5099.1    Sumatera
# ...                       ...             ...         ...
# 5724                    4.961          5228.1  Kalimantan
# 5725                    4.855          5191.0    Sulawesi
# 5726                    4.857          5191.0         NTB
# 5727                    4.961          5228.1       Papua
# 5728                    4.960          5228.1    Sumatera
#
# [5729 rows x 21 columns]

# %%
categorical_columns = [
    'pekerjaan', 'status_perkawinan', 'pendidikan', 'gagal_bayar_sebelumnya',
    'pinjaman_rumah', 'pinjaman_pribadi', 'jenis_kontak', 'bulan_kontak_terakhir',
    'hari_kontak_terakhir', 'hasil_kampanye_sebelumnya'
]

# Step 1: Do NOT drop rows with 'unknown' but keep 'unknown' as a category
# Just ensure categorical columns are strings to prevent errors
for col in categorical_columns:
    df[col] = df[col].astype(str)

# %%
# Target and features
y = df["berlangganan_deposito"]
X = df.drop(columns=["berlangganan_deposito", "customer_number"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
numerical_features = [
    'usia', 'jumlah_kontak_kampanye_ini', 'hari_sejak_kontak_sebelumnya',
    'jumlah_kontak_sebelumnya', 'tingkat_variasi_pekerjaan',
    'indeks_harga_konsumen', 'indeks_kepercayaan_konsumen',
    'suku_bunga_euribor_3bln', 'jumlah_pekerja'
]

# Step 2: Split before imputation/scaling to avoid data leakage
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42
)

# %%
# Step 3: Impute numerical features with median (fit only on train)
num_imputer = SimpleImputer(strategy='median')
X_train_num = num_imputer.fit_transform(X_train[numerical_features])
X_test_num = num_imputer.transform(X_test[numerical_features])

# %%
# Optional: Simple outlier treatment (clip to 1st and 99th percentile in training set)
lower_bounds = np.percentile(X_train_num, 1, axis=0)
upper_bounds = np.percentile(X_train_num, 99, axis=0)
X_train_num = np.clip(X_train_num, lower_bounds, upper_bounds)
X_test_num = np.clip(X_test_num, lower_bounds, upper_bounds)

# %%
# Step 4: Scale numerical features
scaler = StandardScaler()
X_train_num_scaled = scaler.fit_transform(X_train_num)
X_test_num_scaled = scaler.transform(X_test_num)

# %%
# Step 5: Impute categorical features - treat 'unknown' as valid category (no imputation needed if 'unknown' present)
# But if missing values exist, impute with 'Missing'
cat_imputer = SimpleImputer(strategy='constant', fill_value='Missing')
X_train_cat_imputed = cat_imputer.fit_transform(X_train[categorical_columns])
X_test_cat_imputed = cat_imputer.transform(X_test[categorical_columns])

# %%
# Step 6: One-hot encode categorical features
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
X_train_cat = encoder.fit_transform(X_train_cat_imputed)
X_test_cat = encoder.transform(X_test_cat_imputed)

# %%
# Step 7: Combine numerical and categorical features
X_train_final = np.hstack([X_train_num_scaled, X_train_cat])
X_test_final = np.hstack([X_test_num_scaled, X_test_cat])

# %%
# Step 8: Balance training data with SMOTE
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train_final, y_train)

# %%
# Now X_train_res, y_train_res are ready for training your model,
# and X_test_final, y_test for evaluation

# %%
# Example model with class weighting to handle imbalance
model = LogisticRegression(class_weight='balanced', random_state=42, max_iter=1000)

# %%
# Train on your balanced or original training data (here, without SMOTE for example)
model.fit(X_train_final, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
# Predict probabilities on test set (for log loss, use predict_proba)
y_pred_proba = model.predict_proba(X_test_final)[:, 1]  # probability of positive class

# %%
# Calculate log loss on test set
loss = log_loss(y_test, y_pred_proba)
print(f"Log Loss: {loss:.4f}")
# Out:
# Log Loss: 0.5176

# %%
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],        # Regularization strength
    'penalty': ['l1', 'l2', 'elasticnet'],      # Different penalty terms
    'solver': ['liblinear', 'saga']             # solvers compatible with l1/elasticnet
}

# %%
# Set up Stratified K-Fold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_search = GridSearchCV(
    LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42),
    param_grid,
    scoring='neg_log_loss',   # we want to minimize log loss
    cv=cv,
    verbose=1,
    n_jobs=-1
)

# %%
grid_search.fit(X_train_final, y_train)

print(f"Best params: {grid_search.best_params_}")
print(f"Best log loss (negative): {grid_search.best_score_:.4f}")
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# c:\Users\Geovanka\Documents\GitHub\DataQuest_Deposito\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Geovanka\Documents\GitHub\DataQuest_Deposito\.venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Geovanka\Documents\GitHub\DataQuest_Deposito\.venv\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Geovanka\Documents\GitHub\DataQuest_Deposito\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Geovanka\Documents\GitHub\DataQuest_Deposito\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py", line 71, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Geovanka\Documents\GitHub\DataQuest_Deposito\.venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Geovanka\Documents\GitHub\DataQuest_Deposito\.venv\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Geovanka\Documents\GitHub\DataQuest_Deposito\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1203, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Geovanka\Documents\GitHub\DataQuest_Deposito\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [-0.66107634 -0.56706395 -0.54494999 -0.53688936         nan         nan
#  -0.54421728 -0.53492041 -0.5284844  -0.52745776         nan         nan
#  -0.52607548 -0.52599891 -0.52546681 -0.52538865         nan         nan
#  -0.52491721 -0.52490629 -0.52497181 -0.52496756         nan         nan
#  -0.52512741 -0.52511374 -0.52508551 -0.52508201         nan         nan
#  -0.52527499 -0.52518039 -0.52519612 -0.52517154         nan         nan]
#   warnings.warn(
# Best params: {'C': 1, 'penalty': 'l1', 'solver': 'saga'}
# Best log loss (negative): -0.5249

# %%
# Evaluate best model on test set
best_model = grid_search.best_estimator_
y_test_pred_proba = best_model.predict_proba(X_test_final)[:, 1]
test_loss = log_loss(y_test, y_test_pred_proba)
print(f"Test Log Loss with best params: {test_loss:.4f}")
# Out:
# Test Log Loss with best params: 0.5173

# %%
from sklearn.metrics import accuracy_score

# Predict labels (not probabilities) on the test set
y_pred = best_model.predict(X_test_final)

# Calculate accuracy
acc = accuracy_score(y_test, y_pred)

print(f"Accuracy on test set: {acc:.4f}")
# Out:
# Accuracy on test set: 0.8113

# %%
# Get feature names from preprocessing
# Combine numerical + one-hot encoded feature names
feature_names_num = numerical_features
feature_names_cat = encoder.get_feature_names_out(categorical_columns)
all_feature_names = list(feature_names_num) + list(feature_names_cat)

# Coefficients
coefficients = model.coef_[0]  # since it's binary classification
intercept = model.intercept_[0]

# Print model equation
print(f"Model equation:")
print(f"Logit(P) = {intercept:.4f}", end=" ")
for name, coef in zip(all_feature_names, coefficients):
    print(f"+ ({coef:.4f}) * {name}", end=" ")
# Out:
# Model equation:
# Logit(P) = -0.0618 + (0.0229) * usia + (-0.1197) * jumlah_kontak_kampanye_ini + (-0.2482) * hari_sejak_kontak_sebelumnya + (-0.1303) * jumlah_kontak_sebelumnya + (-1.8276) * tingkat_variasi_pekerjaan + (0.8840) * indeks_harga_konsumen + (0.0442) * indeks_kepercayaan_konsumen + (0.3689) * suku_bunga_euribor_3bln + (0.1085) * jumlah_pekerja + (-0.2861) * pekerjaan_asisten rumah tangga + (-0.0210) * pekerjaan_entrepreneur + (0.2746) * pekerjaan_mahasiswa + (-0.0223) * pekerjaan_manajer + (-0.0874) * pekerjaan_pekerja kasar + (0.1437) * pekerjaan_pemilik bisnis + (0.0609) * pekerjaan_pengangguran + (0.2621) * pekerjaan_pensiunan + (-0.1333) * pekerjaan_penyedia jasa + (0.0158) * pekerjaan_sosial media specialis + (0.0465) * pekerjaan_teknisi + (-0.3001) * pekerjaan_unknown + (-0.0903) * status_perkawinan_cerai + (-0.0248) * status_perkawinan_lajang + (-0.0923) * status_perkawinan_menikah + (0.1609) * status_perkawinan_unknown + (-0.1090) * pendidikan_Diploma + (0.0136) * pendidikan_Pendidikan Tinggi + (0.0835) * pendidikan_SD + (-0.1175) * pendidikan_SMA + (-0.0733) * pendidikan_SMP + (0.1270) * pendidikan_TIDAK SEKOLAH + (-0.0211) * pendidikan_Tidak Tamat SD + (0.0504) * pendidikan_unknown + (0.1224) * gagal_bayar_sebelumnya_no + (-0.1341) * gagal_bayar_sebelumnya_unknown + (-0.0349) * gagal_bayar_sebelumnya_yes + (0.0075) * pinjaman_rumah_no + (-0.0434) * pinjaman_rumah_unknown + (-0.0107) * pinjaman_rumah_yes + (-0.0033) * pinjaman_pribadi_no + (-0.0434) * pinjaman_pribadi_unknown + (0.0001) * pinjaman_pribadi_yes + (0.2694) * jenis_kontak_cellular + (-0.3160) * jenis_kontak_telephone + (-0.2232) * bulan_kontak_terakhir_apr + (0.4353) * bulan_kontak_terakhir_aug + (0.3675) * bulan_kontak_terakhir_dec + (0.0155) * bulan_kontak_terakhir_jul + (-0.5945) * bulan_kontak_terakhir_jun + (0.9661) * bulan_kontak_terakhir_mar + (-0.5332) * bulan_kontak_terakhir_may + (-0.5255) * bulan_kontak_terakhir_nov + (0.1486) * bulan_kontak_terakhir_oct + (-0.1031) * bulan_kontak_terakhir_sep + (0.0571) * hari_kontak_terakhir_fri + (-0.2146) * hari_kontak_terakhir_mon + (0.0024) * hari_kontak_terakhir_thu + (0.0663) * hari_kontak_terakhir_tue + (0.0423) * hari_kontak_terakhir_wed + (-0.2852) * hasil_kampanye_sebelumnya_failure + (-0.1212) * hasil_kampanye_sebelumnya_nonexistent + (0.3598) * hasil_kampanye_sebelumnya_success

# %%
import numpy as np

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Example for first row of test set
z = intercept + np.dot(X_test_final[0], coefficients)
prob = sigmoid(z)
print(f"Predicted probability: {prob:.4f}")
# Out:
# Predicted probability: 0.6432

# %%
from sklearn.metrics import log_loss

# Predict probabilities for log loss
y_pred_proba = best_model.predict_proba(X_test_final)

# Log loss
ll = log_loss(y_test, y_pred_proba)

print(f"Log Loss on test set: {ll:.4f}")
print(f"Accuracy on test set: {acc:.4f}")
# Out:
# Log Loss on test set: 0.5173
# Accuracy on test set: 0.8113
