# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE

# %%
df_train = pd.read_csv("training_dataset.csv")
df_val = pd.read_csv("validation_set.csv")

# %%
categorical_columns = [
    'pekerjaan', 'status_perkawinan', 'pendidikan', 'gagal_bayar_sebelumnya',
    'pinjaman_rumah', 'pinjaman_pribadi', 'jenis_kontak', 'bulan_kontak_terakhir',
    'hari_kontak_terakhir', 'hasil_kampanye_sebelumnya'
]

# %%
def count_unknown(df, categorical_cols):
    mask = df[categorical_cols].isin(['unknown']).any(axis=1)
    return mask.sum()

# Sebelum dihapus
unknown_train_before = count_unknown(df_train, categorical_columns)
unknown_val_before = count_unknown(df_val, categorical_columns)
print(f"Jumlah baris dengan 'unknown' di train sebelum dihapus: {unknown_train_before}")
print(f"Jumlah baris dengan 'unknown' di val sebelum dihapus: {unknown_val_before}")
# Out:
# Jumlah baris dengan 'unknown' di train sebelum dihapus: 5968
# Jumlah baris dengan 'unknown' di val sebelum dihapus: 1476

# %%
df_train_clean = df_train[~df_train[categorical_columns].isin(['unknown']).any(axis=1)].reset_index(drop=True)
df_val_clean = df_val[~df_val[categorical_columns].isin(['unknown']).any(axis=1)].reset_index(drop=True)

# %%
unknown_train_after = count_unknown(df_train_clean, categorical_columns)
unknown_val_after = count_unknown(df_val_clean, categorical_columns)
print(f"Jumlah baris dengan 'unknown' di train setelah dihapus: {unknown_train_after}")
print(f"Jumlah baris dengan 'unknown' di val setelah dihapus: {unknown_val_after}")
# Out:
# Jumlah baris dengan 'unknown' di train setelah dihapus: 0
# Jumlah baris dengan 'unknown' di val setelah dihapus: 0

# %%
df_train_clean
# Out:
#        customer_number  usia               pekerjaan status_perkawinan  \
# 0               531036    63  sosial media specialis           menikah
# 1               999241    43                 teknisi           menikah
# 2               995002    29  sosial media specialis            lajang
# 3               932750    40           pekerja kasar           menikah
# 4               684699    40  sosial media specialis            lajang
# ...                ...   ...                     ...               ...
# 16943           137521    29  sosial media specialis            lajang
# 16944           133325    30               mahasiswa            lajang
# 16945           680377    32                 teknisi           menikah
# 16946           505429    30               mahasiswa            lajang
# 16947           308952    29                 manajer            lajang
#
#               pendidikan gagal_bayar_sebelumnya pinjaman_rumah  \
# 0      Pendidikan Tinggi                     no            yes
# 1      Pendidikan Tinggi                     no            yes
# 2      Pendidikan Tinggi                     no            yes
# 3                    SMA                     no             no
# 4      Pendidikan Tinggi                     no             no
# ...                  ...                    ...            ...
# 16943  Pendidikan Tinggi                     no            yes
# 16944            Diploma                     no             no
# 16945            Diploma                     no            yes
# 16946            Diploma                     no             no
# 16947                SMA                     no            yes
#
#       pinjaman_pribadi jenis_kontak bulan_kontak_terakhir  ...  \
# 0                   no     cellular                   jul  ...
# 1                   no     cellular                   nov  ...
# 2                  yes     cellular                   jul  ...
# 3                   no    telephone                   may  ...
# 4                   no     cellular                   aug  ...
# ...                ...          ...                   ...  ...
# 16943              yes     cellular                   aug  ...
# 16944               no     cellular                   sep  ...
# 16945               no     cellular                   aug  ...
# 16946               no    telephone                   sep  ...
# 16947               no     cellular                   jul  ...
#
#       hari_sejak_kontak_sebelumnya  jumlah_kontak_sebelumnya  \
# 0                              999                         0
# 1                              999                         0
# 2                              999                         0
# 3                              999                         0
# 4                              999                         0
# ...                            ...                       ...
# 16943                          999                         0
# 16944                            9                         2
# 16945                          999                         0
# 16946                          999                         0
# 16947                          999                         0
#
#        hasil_kampanye_sebelumnya  tingkat_variasi_pekerjaan  \
# 0                    nonexistent                       -1.7
# 1                    nonexistent                       -0.1
# 2                    nonexistent                        1.4
# 3                    nonexistent                        1.1
# 4                    nonexistent                        1.4
# ...                          ...                        ...
# 16943                nonexistent                        1.4
# 16944                    failure                       -1.1
# 16945                nonexistent                        1.4
# 16946                nonexistent                       -1.1
# 16947                nonexistent                        1.4
#
#       indeks_harga_konsumen  indeks_kepercayaan_konsumen  \
# 0                    94.215                        -40.3
# 1                    93.200                        -42.0
# 2                    93.918                        -42.7
# 3                    93.994                        -36.4
# 4                    93.444                        -36.1
# ...                     ...                          ...
# 16943                93.444                        -36.1
# 16944                94.199                        -37.5
# 16945                93.444                        -36.1
# 16946                94.199                        -37.5
# 16947                93.918                        -42.7
#
#        suku_bunga_euribor_3bln  jumlah_pekerja       pulau  \
# 0                        0.885          4991.6       Papua
# 1                        4.021          5195.8    Sulawesi
# 2                        4.958          5228.1       Papua
# 3                        4.859          5191.0    Sumatera
# 4                        4.964          5228.1        Bali
# ...                        ...             ...         ...
# 16943                    4.963          5228.1         NTT
# 16944                    0.879          4963.6        Bali
# 16945                    4.967          5228.1  Kalimantan
# 16946                    0.880          4963.6        Bali
# 16947                    4.962          5228.1         NTT
#
#        berlangganan_deposito
# 0                          1
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 16943                      0
# 16944                      0
# 16945                      0
# 16946                      0
# 16947                      0
#
# [16948 rows x 22 columns]

# %%
df_val_clean
# Out:
#       customer_number  usia               pekerjaan status_perkawinan  \
# 0              445420    35           penyedia jasa           menikah
# 1              816820    51            pengangguran           menikah
# 2              542716    45                 teknisi             cerai
# 3              434084    32  sosial media specialis            lajang
# 4              159684    61               pensiunan             cerai
# ...               ...   ...                     ...               ...
# 4248           214452    27  sosial media specialis            lajang
# 4249           588935    38          pemilik bisnis             cerai
# 4250           782072    51           pekerja kasar           menikah
# 4251           116371    30           pekerja kasar           menikah
# 4252           986050    46  sosial media specialis            lajang
#
#              pendidikan gagal_bayar_sebelumnya pinjaman_rumah  \
# 0                   SMA                     no            yes
# 1               Diploma                     no             no
# 2                   SMA                     no            yes
# 3                   SMA                     no             no
# 4     Pendidikan Tinggi                     no            yes
# ...                 ...                    ...            ...
# 4248  Pendidikan Tinggi                     no            yes
# 4249                SMP                     no            yes
# 4250     Tidak Tamat SD                     no            yes
# 4251                SMP                     no            yes
# 4252                SMA                     no             no
#
#      pinjaman_pribadi jenis_kontak bulan_kontak_terakhir  ...  \
# 0                 yes     cellular                   jul  ...
# 1                  no    telephone                   may  ...
# 2                  no     cellular                   may  ...
# 3                  no    telephone                   jun  ...
# 4                  no     cellular                   apr  ...
# ...               ...          ...                   ...  ...
# 4248               no     cellular                   apr  ...
# 4249               no    telephone                   may  ...
# 4250               no    telephone                   jun  ...
# 4251              yes    telephone                   may  ...
# 4252               no    telephone                   jun  ...
#
#      jumlah_kontak_kampanye_ini  hari_sejak_kontak_sebelumnya  \
# 0                             1                           999
# 1                             3                           999
# 2                             1                           999
# 3                             1                           999
# 4                             2                           999
# ...                         ...                           ...
# 4248                          1                           999
# 4249                          3                           999
# 4250                          1                           999
# 4251                          1                           999
# 4252                          1                           999
#
#       jumlah_kontak_sebelumnya  hasil_kampanye_sebelumnya  \
# 0                            0                nonexistent
# 1                            0                nonexistent
# 2                            1                    failure
# 3                            0                nonexistent
# 4                            0                nonexistent
# ...                        ...                        ...
# 4248                         0                nonexistent
# 4249                         0                nonexistent
# 4250                         0                nonexistent
# 4251                         0                nonexistent
# 4252                         0                nonexistent
#
#      tingkat_variasi_pekerjaan  indeks_harga_konsumen  \
# 0                          1.4                 93.918
# 1                          1.1                 93.994
# 2                         -1.8                 92.893
# 3                          1.4                 94.465
# 4                         -1.8                 93.075
# ...                        ...                    ...
# 4248                      -1.8                 93.075
# 4249                       1.1                 93.994
# 4250                       1.4                 94.465
# 4251                       1.1                 93.994
# 4252                       1.4                 94.465
#
#       indeks_kepercayaan_konsumen  suku_bunga_euribor_3bln  jumlah_pekerja  \
# 0                           -42.7                    4.960          5228.1
# 1                           -36.4                    4.857          5191.0
# 2                           -46.2                    1.327          5099.1
# 3                           -41.8                    4.864          5228.1
# 4                           -47.1                    1.384          5099.1
# ...                           ...                      ...             ...
# 4248                        -47.1                    1.392          5099.1
# 4249                        -36.4                    4.857          5191.0
# 4250                        -41.8                    4.961          5228.1
# 4251                        -36.4                    4.855          5191.0
# 4252                        -41.8                    4.960          5228.1
#
#            pulau
# 0           Jawa
# 1       Sumatera
# 2       Sumatera
# 3          Papua
# 4     Kalimantan
# ...          ...
# 4248    Sulawesi
# 4249       Papua
# 4250  Kalimantan
# 4251    Sulawesi
# 4252    Sumatera
#
# [4253 rows x 21 columns]

# %%
y_train = df_train["berlangganan_deposito"]
X_train = df_train.drop(columns=["berlangganan_deposito", "customer_number"])
X_val = df_val.drop(columns=["customer_number"])
val_customer_number = df_val["customer_number"]

# %%
categorical_features = categorical_columns
numerical_features = [
    'usia', 'jumlah_kontak_kampanye_ini', 'hari_sejak_kontak_sebelumnya',
    'jumlah_kontak_sebelumnya', 'tingkat_variasi_pekerjaan',
    'indeks_harga_konsumen', 'indeks_kepercayaan_konsumen',
    'suku_bunga_euribor_3bln', 'jumlah_pekerja'
]

# %%
categorical_features = categorical_columns

# Imputer untuk numerik (jika ada missing)
num_imputer = SimpleImputer(strategy='median')
X_train_num = num_imputer.fit_transform(X_train[numerical_features])
X_val_num = num_imputer.transform(X_val[numerical_features])

# %%
# Scaling numerik
scaler = StandardScaler()
X_train_num_scaled = scaler.fit_transform(X_train_num)
X_val_num_scaled = scaler.transform(X_val_num)

# %%
# Kategorikal langsung encoding tanpa imputer
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
X_train_cat_enc = encoder.fit_transform(X_train[categorical_features])
X_val_cat_enc = encoder.transform(X_val[categorical_features])

# %%
X_train_final = np.hstack([X_train_num_scaled, X_train_cat_enc])
X_val_final = np.hstack([X_val_num_scaled, X_val_cat_enc])

# %%
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train_final, y_train)

# %%
clf = RandomForestClassifier(random_state=42)
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5]
}
grid = GridSearchCV(clf, param_grid, cv=5, scoring='f1', n_jobs=-1, verbose=1)
grid.fit(X_train_res, y_train_res)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, None],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='f1', verbose=1)

# %%
print("\n Best Parameters:", grid.best_params_)
# Out:
#  Best Parameters: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 100}

# %%
y_val_pred = grid.predict(X_val_final)

# %%
output = pd.DataFrame({
    "customer_number": val_customer_number,
    "berlangganan_deposito": y_val_pred
})

# %%
output
# Out:
#       customer_number  berlangganan_deposito
# 0              445420                      0
# 1              816820                      0
# 2              542716                      0
# 3              434084                      0
# 4              159684                      1
# ...               ...                    ...
# 4248           214452                      1
# 4249           588935                      0
# 4250           782072                      0
# 4251           116371                      0
# 4252           986050                      0
#
# [4253 rows x 2 columns]
